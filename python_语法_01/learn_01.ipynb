# %%
import turtle

user_names = ["赵敏", "王刚", "赵本山", "赵小环"]
print(len(user_names))
pop = user_names.pop(0)
print(pop, len(user_names))
print(user_names, len(user_names))
# Out:
# 4
# 赵敏 3
# ['王刚', '赵本山', '赵小环'] 3

# %%
"""

learn_01_qw_agent.py - 语法学习

"""
print("hello world")
# Out:
# hello world

# %%
balance = 0


def deposit(amount):
    global balance
    balance += amount
    print(f"Deposited {amount}, new balance is {balance}")


def withdraw(amount):
    global balance
    if amount > balance:
        print("Insufficient funds")
    else:
        balance -= amount
        print(f"Withdrew {amount}, new balance is {balance}")


deposit(100)
withdraw(50)
withdraw(60)
# Out:
# Deposited 100, new balance is 100
# Withdrew 50, new balance is 50
# Insufficient funds

# %%
balance: int = 1
user_name: str = "Alice"
user_sex: str = "Female"
age: int = 18
print(f"{user_name} is a {user_sex} and her balance is {balance}")
user_name_type = type(user_name)
int_type = type(age)
print(user_name_type, int_type)
# Out:
# Alice is a Female and her balance is 1
# <class 'str'> <class 'int'>

# %%
user_names = ["赵敏", "王刚", "赵本山", "赵小环"]
for i in range(0, len(user_names)):
    print(user_names[i])
    if user_names[i].startswith("赵"):
        print(user_names[i])
        user_names[i] = "王" + user_names[i][1:]
        print(user_names[i])
# Out:
# 赵敏
# 赵敏
# 王敏
# 王刚
# 赵本山
# 赵本山
# 王本山
# 赵小环
# 赵小环
# 王小环

# %%
t = (1, 2)
a, b = t
print(a, b)
print(l)
# Out:
# 1 2

# %%
l = list()
l.append(1)
l.append(2)
#print(l)
l1 = [1, 2, 3, 4, 5, 899, ]
print(l1)
print(l1[0:-2])
# Out:
# [1, 2, 3, 4, 5, 899]
# [1, 2, 3, 4]

# %%
dict = {"k1": 1, "k2": 2}
for k, v in dict.items():
    print(k, v)
# Out:
# k1 1
# k2 2

# %%
lset = set()
lset.add(1)
lset.add(2)
print(lset)

lset.add(1)
print(lset)
# Out:
# {1, 2}
# {1, 2}

# %%
s: int = 1
print(f'{s}')
# Out:
# 1
